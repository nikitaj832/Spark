# %%
# %sql
SHOW EXTERNAL LOCATIONS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>url</th><th>comment</th></tr></thead><tbody><tr><td>db_s3_external_databricks-s3-ingest-19fd5</td><td>s3://niki-19/</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
CREATE TABLE my_tables
USING DELTA
LOCATION 's3://niki-19/my_tables';

# %%
df = spark.read.option("header", True).csv("s3://niki-19/insurance.csv")
df.show()
# Out:
# +---+------+------+--------+------+---------+-----------+
# |age|   sex|   bmi|children|smoker|   region|    charges|
# +---+------+------+--------+------+---------+-----------+
# | 19|female|  27.9|       0|   yes|southwest|  16884.924|
# | 18|  male| 33.77|       1|    no|southeast|  1725.5523|
# | 28|  male|    33|       3|    no|southeast|   4449.462|
# | 33|  male|22.705|       0|    no|northwest|21984.47061|
# | 32|  male| 28.88|       0|    no|northwest|  3866.8552|
# | 31|female| 25.74|       0|    no|southeast|  3756.6216|
# | 46|female| 33.44|       1|    no|southeast|  8240.5896|
# | 37|female| 27.74|       3|    no|northwest|  7281.5056|
# | 37|  male| 29.83|       2|    no|northeast|  6406.4107|
# | 60|female| 25.84|       0|    no|northwest|28923.13692|
# | 25|  male| 26.22|       0|    no|northeast|  2721.3208|
# | 62|female| 26.29|       0|   yes|southeast| 27808.7251|
# | 23|  male|  34.4|       0|    no|southwest|   1826.843|
# ...
